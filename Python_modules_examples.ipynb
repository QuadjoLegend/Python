# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/Python-Notebook-Banners/Examples.png"  style="display: block; margin-left: auto; margin-right: auto;";/>
# </div>

# %% [markdown]
# # Examples: Python modules

# %% [markdown]
# This notebook accompanies the walk-through video on Python modules and packages and also contains a few additional examples on how we can use modules.

# %% [markdown]
# ## Learning objectives
# In this train, we will learn how to:
# - Write a module and import all or specific objects from a module.
# - Import modules using an alias name and explore the use of built-in modules.
#
#
# ## Outline
# To do this, we will:
# - Define the importance of modules and packages in programming.
# - Review the syntax and conventions for importing modules.
# - Consider the use of built-in Python modules.

# %% [markdown]
# ## Introduction
# Modular programming is a style of programming that promotes code reusability, allowing us to generate single pieces of code which can be used in multiple parts of a project – thus saving time and resources. The resulting code can be simpler to understand and maintain since components can be considered in isolation. In Python, **modularisation** is implemented using functions, modules, and packages.
#
# A **module** is a file consisting of Python code. A module can define functions, classes, variables, and runnable code. These modules can be imported and referenced from other Python code. A **Python package** (also referred to as a library) is a collection of hierarchically structured directories of Python code consisting of sub-packages and modules.
#
# Modules and packages are two mechanisms that facilitate modular programming.
#
# ## Why modularisation?
#
# * **Reusability**: Eliminates the need to write new code, as functionality defined in a single module can be easily reused.
#
#
# * **Simplicity**: Modules generally tend to focus on a selected area of the problem which is usually small, rather than focusing on the entire problem at hand. Integrating the use of selected modules will result in systematically dealing with each small problem in the code, making development easier and less error-prone.
#
#
# * **Maintainability**: Modules in Python are often designed to be self-supporting. In this sense, one module does not depend entirely upon other modules to work. Therefore, it is unlikely that modifying a single module of a program will affect other parts of the program. This allows a team of many programmers or data scientists to work collaboratively on a large application.

# %% [markdown]
# ## Working with modules
#
# ### Creating modules
# Creating a module is as simple as saving a Python script with functions, classes, variables and running code. The file name is the module name with the suffix `.py` appended.
#
# ### Importing modules
# We can access this module and its elements from a different Python file by using the `import` statement.
# * We can import a single module/package:
#
#     ```python
#     import <module_name>
#     ```
#
# * Import multiple modules using individual import statements:
#
#     ```python
#     import <module_1_name>
#     import <module_2_name>
#     import <module_3_name>
#     ...```
#
#
#
# The same rules apply when dealing with packages. We can import specific modules within a package by using dot notation. For this to work, we have to structure packages and modules in a way that reflects the hierarchy in the package directory.
#
#    ```python
#     import <package_name>.<sub_package_name>.<module_name>.<...>
#    ```
#
# Let's go ahead and create our own module, with the following three types of elements:
#
# *   A variable `s`
# *   A function `say_hi()`
# *   A class `Greet`

# %%
# Contents of the module we are creating 
content = """
s = 'Hello ' 

def say_hi(name):
    print(s + name)

class Greet:
    pass
"""

# Write the above text to a file called my_module.py
# within our current working directory. 
with open('./my_module.py', 'w') as fp:
    fp.write(content)

# %% [markdown]
# This command writes (or saves) our module into our working directory so that we can use it again.

# %%
#Import the module we've just made! 
import my_module

# %% [markdown]
# Even though we've imported our module, note that its contents (the variables and functions we've defined within the module) are not directly accessible to us. As such, attempting to access these elements will result in (namespace) errors being thrown. We can safely see such errors using a `try-except` block:

# %%
try:
    # Try to print the variable s
    print(s)
except NameError:
    # We've caught a NameError exception (error!)
    # We inform the programmer (you) that the variable does not exist
    print("Variable 's' does not exist!")
# Out:
# Variable 's' does not exist!

# %% [markdown]
# Learning from this experience, it is important to know that objects in a module are only accessible when prefixed with via dot notation, as illustrated below.

# %%
# Accessing the variable s in my_module
my_module.s
# Out:
# 'Hello '

# %%
# Accessing the say_hi function in my_module
my_module.say_hi('Nelson')
# Out:
# Hello Nelson

# %% [markdown]
# ### Example: Importing modules using an alias
# The `import` statement in Python also allows for the use of aliases when referencing a module. Using the `as` keyword, we can save ourselves from having to type otherwise long package names each time we need to access an object from a given module/package. This usually follows the following syntax:
#
# ```python
# import <module_name> as <new_model_name>
# ```
# or
#
# ```python
# from <package_name> import <module_name> as <new_model_name>
# ```
#
# For example:

# %%
# Alias for my_module
import my_module as md

# %% [markdown]
# We can thus treat the alias as the new name for the module.

# %%
# Accessing the variable s using an alias
md.s

# %%
# Accessing the say_hi function using an alias for my_module
md.say_hi('Jabulani')

# %%
# Accessing the empty class, Greet
md.Greet

# %% [markdown]
# ### Example: Importing modules directly
# Another way to access specific objects in a module is to use the `from` keyword and import them directly:
#
# ```python
# from <module_name> import <x, y, z>
# ```

# %%
from my_module import s, say_hi, Greet

# %%
s
# Out:
# 'Hello '

# %%
say_hi('Jabulani')
# Out:
# Hello Jabulani

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# We can see that using the `from xx import yy` structure provides access to the individual elements in the module without having to use dot notation. However, using aliases is the recommended way of importing modules and packages, as this prevents potential confusion when different modules contain functions or classes with the same name.
#
# To select all objects from a module we can use the following command, where the asterisk **( * )** *signifies all* :
#
# ```python
# from <module_name> import*
# ```
# Let's see this in practice one more time:

# %%
from my_module import *

# %% [markdown]
# Now we have access to all our module contents.

# %%
say_hi('Joanne')
# Out:
# Hello Joanne

# %%
Greet
# Out:
# my_module.Greet

# %% [markdown]
# ## Built-in modules
# Python contains a large number of what are known as 'built-in' modules. These modules can be accessed in Python programs by simply importing them using their name preceded by the keyword `import`.
#
# Each built-in module contains resources for certain system-specific functionalities such as operating system management, disk input-output, etc. Python scripts (with the **.py** extension) containing useful utilities are embedded within the standard library.
#
# To **display a list of all available modules**, use the following command:
#
# `help('modules')`

# %%
help('modules') # this might take a while
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\YOGA\anaconda3\Lib\site-packages\nltk\twitter\__init__.py:20: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# C:\Users\YOGA\anaconda3\Lib\site-packages\pydantic\experimental\__init__.py:7: PydanticExperimentalWarning:
#
# This module is experimental, its contents are subject to change and deprecation.
# pygame 2.6.1 (SDL 2.28.4, Python 3.13.5)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# C:\Users\YOGA\anaconda3\Lib\pkgutil.py:78: UserWarning:
#
# The superqt.qtcompat module is deprecated as of v0.3.0. Please import from `qtpy` instead.
# 3204bda914b7f2c6f497__mypyc cProfile            math                service_identity
# IPython             cachetools          matplotlib          servicemanager
# MySQLdb             calendar            matplotlib_inline   setup_cython
# OpenSSL             certifi             mccabe              setuptools
# PIL                 cffi                mdit_py_plugins     shellingham
# PyQt5               chardet             mdurl               shelve
# __future__          charset_normalizer  menuinst            shlex
# __hello__           click               mimetypes           shutil
# __phello__          cloudpickle         mistune             signal
# _abc                cmath               mkl                 sipbuild
# _aix_support        cmd                 mkl_fft             site
# _android_support    code                mkl_random          six
# _apple_support      codecs              mmap                skimage
# _argon2_cffi_bindings codeop              mmapfile            sklearn
# _ast                collections         mmsystem            sklearn_compat
# _asyncio            colorama            modulefinder        slugify
# _bisect             colorcet            more_itertools      smmap
# _black_version      colorsys            mpmath              smtplib
# _blake2             comm                msgpack             sniffio
# _brotli             commctrl            msvcrt              snowballstemmer
# _bz2                compileall          multidict           socket
# _cffi_backend       concurrent          multipledispatch    socketserver
# _codecs             conda               multiprocessing     socks
# _codecs_cn          conda_anaconda_telemetry my_module           sockshandler
# _codecs_hk          conda_anaconda_tos  mypy                sortedcontainers
# _codecs_iso2022     conda_build         mypy_extensions     soupsieve
# _codecs_jp          conda_content_trust mypyc               sphinx
# _codecs_kr          conda_env           nacl                spyder
# _codecs_tw          conda_index         narwhals            spyder_kernels
# _collections        conda_libmamba_solver navigator_updater   sql
# _collections_abc    conda_pack          nb_conda_kernels    sqlalchemy
# _colorize           conda_package_handling nbclient            sqlite3
# _compat_pickle      conda_package_streaming nbconvert           sqlparse
# _compression        conda_token         nbformat            sre_compile
# _contextvars        configparser        nest_asyncio        sre_constants
# _csv                constantly          netbios             sre_parse
# _ctypes             contextlib          netrc               ssl
# _ctypes_test        contextvars         networkx            sspi
# _datetime           contourpy           nltk                sspicon
# _decimal            cookiecutter        notebook            stack_data
# _distutils_hack     copy                notebook_shim       start_pythonwin
# _elementtree        copyreg             nt                  stat
# _functools          cpuinfo             ntpath              statistics
# _hashlib            cryptography        ntsecuritycon       statsmodels
# _heapq              cssselect           nturl2path          streamlit
# _imp                csv                 numba               string
# _interpchannels     ctypes              numbergen           stringprep
# _interpqueues       curl                numbers             struct
# _interpreters       curses              numexpr             subprocess
# _io                 cwp                 numpy               superqt
# _ios_support        cycler              numpydoc            sympy
# _json               cytoolz             odbc                symtable
# _locale             dask                opcode              sys
# _lsprof             dask_expr           openpyxl            sysconfig
# _lzma               dataclasses         operator            tables
# _markupbase         datashader          optparse            tabnanny
# _md5                datetime            ordered_set         tabulate
# _multibytecodec     dateutil            os                  tarfile
# _multiprocessing    dbm                 overrides           tblib
# _nsis               dde                 packaging           tempfile
# _opcode             debugpy             pandas              tenacity
# _opcode_metadata    decimal             pandocfilters       terminado
# _operator           decorator           panel               test
# _osx_support        defusedxml          param               test_pycosat
# _overlapped         deprecated          parsel              text_unidecode
# _pickle             diff_match_patch    parso               textdistance
# _plotly_future_     difflib             partd               textwrap
# _plotly_utils       dill                pathlib             this
# _py_abc             dis                 pathspec            threading
# _pydatetime         distributed         patsy               threadpoolctl
# _pydecimal          distro              pdb                 three_merge
# _pydev_bundle       docstring_to_markdown perfmon             tifffile
# _pydev_comm         doctest             pexpect             time
# _pydev_imps         docutils            pickle              timeit
# _pydev_runfiles     dotenv              pickleshare         timer
# _pydevd_bundle      email               pickletools         tinycss2
# _pydevd_frame_eval  encodings           pip                 tkinter
# _pyio               ensurepip           pkce                tldextract
# _pylong             enum                pkg_resources       tlz
# _pyrepl             erfa                pkginfo             token
# _pytest             errno               pkgutil             tokenize
# _queue              et_xmlfile          platform            toml
# _random             evalidate           platformdirs        tomli
# _ruamel_yaml        executing           plistlib            tomlkit
# _sha1               fastjsonschema      plotly              tomllib
# _sha2               faulthandler        pluggy              toolz
# _sha3               filecmp             ply                 tornado
# _signal             fileinput           poplib              tqdm
# _sitebuiltins       filelock            posixpath           trace
# _socket             flake8              poyo                traceback
# _sqlite3            flask               pprint              tracemalloc
# _sre                fnmatch             prettytable         traitlets
# _ssl                fontTools           profile             truststore
# _stat               fractions           prometheus_client   tty
# _statistics         frozendict          prompt_toolkit      turtle
# _string             frozenlist          propcache           turtledemo
# _strptime           fsspec              protego             twisted
# _struct             ftplib              pstats              typeguard
# _suggestions        functools           psutil              typer
# _symtable           gc                  pty                 types
# _sysconfig          genericpath         ptyprocess          typing
# _system_path        getopt              pure_eval           typing_extensions
# _testbuffer         getpass             py                  tzdata
# _testcapi           gettext             py_compile          uc_micro
# _testclinic         git                 pyarrow             ujson
# _testclinic_limited gitdb               pyasn1              unicodedata
# _testconsole        github              pyasn1_modules      unidecode
# _testimportmultiple glob                pyclbr              unittest
# _testinternalcapi   gmpy2               pycodestyle         urllib
# _testlimitedcapi    graphlib            pycompletionserver  urllib3
# _testmultiphase     greenlet            pycosat             uuid
# _testsinglephase    gzip                pycparser           venv
# _thread             h11                 pyct                w3lib
# _threading_local    h5py                pycurl              warnings
# _tkinter            hashlib             pydantic            watchdog
# _tokenize           heapdict            pydantic_core       wave
# _tracemalloc        heapq               pydantic_settings   wcwidth
# _typing             hmac                pydev_app_engine_debug_startup weakref
# _uuid               holoviews           pydev_console       webbrowser
# _warnings           html                pydev_coverage      webencodings
# _weakref            http                pydev_ipython       websocket
# _weakrefset         httpcore            pydev_jupyter_plugin werkzeug
# _win32sysloader     httpx               pydev_jupyter_utils whatthepatch
# _win32verstamp_pywin32ctypes hvplot              pydev_jupyter_vars  wheel
# _winapi             hyperlink           pydev_pysrc         widgetsnbextension
# _winxptheme         idlelib             pydevconsole        win2kras
# _wmi                idna                pydevd              win32api
# _yaml               imageio             pydevd_concurrency_analyser win32clipboard
# _zoneinfo           imagesize           pydevd_file_utils   win32com
# abc                 imaplib             pydevd_plugins      win32con
# adodbapi            imblearn            pydevd_pycharm      win32console
# aext_assistant      importlib           pydevd_tracing      win32cred
# aext_assistant_server importlib_metadata  pydispatch          win32crypt
# aext_core           importlib_resources pydoc               win32cryptcon
# aext_core_server    incremental         pydoc_data          win32ctypes
# aext_environments_server inflect             pydocstyle          win32event
# aext_panels         inflection          pyexpat             win32evtlog
# aext_panels_server  iniconfig           pyflakes            win32evtlogutil
# aext_project_filebrowser_server inspect             pygame              win32file
# aext_share_notebook intake              pygments            win32gui
# aext_share_notebook_server interpreterInfo     pylab               win32gui_struct
# aext_shared         intervaltree        pylint              win32help
# aext_toolbox        io                  pylint_venv         win32inet
# afxres              ipaddress           pyls_spyder         win32inetcon
# aiobotocore         ipykernel           pylsp               win32job
# aiohappyeyeballs    ipykernel_launcher  pylsp_black         win32lz
# aiohttp             ipython_genutils    pylsp_jsonrpc       win32net
# aioitertools        ipywidgets          pymysql             win32netcon
# aiosignal           isapi               pyodbc              win32pdh
# alabaster           isort               pyparsing           win32pdhquery
# alembic             isympy              pytest              win32pdhutil
# algorithms          itemadapter         pythoncom           win32pipe
# altair              itemloaders         pythonjsonlogger    win32print
# anaconda_anon_usage itertools           pytoolconfig        win32process
# anaconda_auth       itsdangerous        pytz                win32profile
# anaconda_catalogs   jedi                pyuca               win32ras
# anaconda_cli_base   jellyfish           pyviz_comms         win32rcparser
# anaconda_cloud_auth jinja2              pywin               win32security
# anaconda_navigator  jinja2_time         pywin32_bootstrap   win32service
# anaconda_project    jmespath            pywin32_testutil    win32serviceutil
# annotated_types     joblib              pywintypes          win32timezone
# antigravity         json                pywt                win32trace
# anyio               json5               qdarkstyle          win32traceutil
# appdirs             jsonpatch           qstylizer           win32transaction
# archspec            jsonpointer         qtawesome           win32ts
# argon2              jsonschema          qtconsole           win32ui
# argparse            jsonschema_specifications qtpy                win32uiole
# array               jupyter             queue               win32verstamp
# arrow               jupyter_client      queuelib            win32wnet
# ast                 jupyter_console     quopri              win_inet_pton
# astroid             jupyter_core        random              winerror
# astropy             jupyter_events      rasutil             winioctlcon
# astropy_iers_data   jupyter_lsp         re                  winnt
# asttokens           jupyter_server      readchar            winperf
# async_lru           jupyter_server_terminals referencing         winpty
# asyncio             jupyterlab          regcheck            winreg
# asyncssh            jupyterlab_plotly   regex               winsound
# atexit              jupyterlab_pygments regutil             winxpgui
# atomicwrites        jupyterlab_server   repo_cli            winxptheme
# attr                jupyterlab_widgets  reprlib             wrapt
# attrs               jwt                 requests            wsgiref
# autocommand         keyring             requests_file       xarray
# automat             keyword             requests_toolbelt   xlwings
# autopep8            kiwisolver          rfc3339_validator   xlwingsjs
# babel               lazy_loader         rfc3986_validator   xml
# backports           lckr_jupyterlab_variableinspector rich                xmlrpc
# base64              libarchive          rlcompleter         xxlimited
# bcrypt              libmambapy          roman_numerals      xxlimited_35
# bdb                 lief                rope                xxsubtype
# binaryornot         linecache           rpds                xyzservices
# binascii            linkify_it          rtree               yaml
# binstar_client      llvmlite            ruamel_yaml         yapf
# bisect              lmdb                runfiles            yapf_third_party
# black               locale              runpy               yapftests
# blackd              locket              s3fs                yarl
# bleach              logging             sched               zict
# blib2to3            lxml                scipy               zipapp
# blinker             lz4                 scrapy              zipfile
# bokeh               lzma                seaborn             zipimport
# boltons             mailbox             search_time_complexity zipp
# botocore            main                secrets             zlib
# bottleneck          mako                select              zmq
# brotli              markdown            selectors           zoneinfo
# bs4                 markdown_it         semver              zope
# builtins            markupsafe          send2trash          zstandard
# bz2                 marshal             sentry_sdk
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %% [markdown]
# Alternatively, the `dir()` function is a built-in function that can be used to **list all the function names (or variable names) in a module**:
#
# `dir(module_name)`

# %%
# Import math module 
import math 

# Use the sqrt function in the math module
x = math.sqrt(81)
print('The square root of 81 is equal to {}'.format(x))

# List all functions in math module 
list_all= dir(math)
print('Functions in the math module: {}'.format(list_all))
# Out:
# The square root of 81 is equal to 9.0
# Functions in the math module: ['__doc__', '__loader__', '__name__', '__package__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'cbrt', 'ceil', 'comb', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'e', 'erf', 'erfc', 'exp', 'exp2', 'expm1', 'fabs', 'factorial', 'floor', 'fma', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'inf', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log10', 'log1p', 'log2', 'modf', 'nan', 'nextafter', 'perm', 'pi', 'pow', 'prod', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'sumprod', 'tan', 'tanh', 'tau', 'trunc', 'ulp']

# %% [markdown]
# ## Summary
#
# In this train, we learned how to create, import, and use modules. We also explored the use of built-in modules in Python and how to determine what functions are present within modules.

# %% [markdown]
# #
#
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/refs/heads/master/ALX_banners/ALX_Navy.png"  style="width:140px";/>
# </div>
